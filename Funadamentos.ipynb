# %% [markdown]
# <a href="https://colab.research.google.com/github/joaorosera/Aula-IA/blob/main/Funadamentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá mundo, estou na aula de Inteligência Artificial.")
# Out:
# Olá mundo, estou na aula de Inteligência Artificial.

# %% [markdown]
# ![vasco.png](data:image/png;base64,...)
